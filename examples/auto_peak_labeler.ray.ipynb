# %%
# Load paths for using psana
# %env SIT_ROOT=/sdf/group/lcls/ds/ana
# %env SIT_DATA=/sdf/group/lcls/ds/ana/sw/conda1/inst/envs/ana-4.0.54-py3/data:/sdf/group/lcls/ds/ana/data/
# %env SIT_PSDM_DATA=/sdf/data/lcls/ds
# Out:
# env: SIT_ROOT=/sdf/group/lcls/ds/ana
# env: SIT_DATA=/sdf/group/lcls/ds/ana/sw/conda1/inst/envs/ana-4.0.54-py3/data:/sdf/group/lcls/ds/ana/data/
# env: SIT_PSDM_DATA=/sdf/data/lcls/ds

# %%
# # Run the notebook as if it's in the PROJECT directory
# %bookmark PROJ_ROOT /reg/data/ana03/scratch/cwang31/pf
# %cd -b PROJ_ROOT

# %%
# !pwd
# Out:
# /sdf/data/lcls/ds/prj/prjcwang31/results/pf

# %% [markdown]
# ## Auto labeler

# %%
# Load paths for using psana
# %env SIT_ROOT=/sdf/group/lcls/ds/ana
# %env SIT_DATA=/sdf/group/lcls/ds/ana/sw/conda1/inst/envs/ana-4.0.54-py3/data:/sdf/group/lcls/ds/ana/data/
# %env SIT_PSDM_DATA=/sdf/data/lcls/ds
# Out:
# env: SIT_ROOT=/sdf/group/lcls/ds/ana
# env: SIT_DATA=/sdf/group/lcls/ds/ana/sw/conda1/inst/envs/ana-4.0.54-py3/data:/sdf/group/lcls/ds/ana/data/
# env: SIT_PSDM_DATA=/sdf/data/lcls/ds

# %%
import ray

# %%
import matplotlib.pyplot       as plt
import matplotlib.colors       as mcolors
import matplotlib.patches      as mpatches
import matplotlib.transforms   as mtransforms
import matplotlib.font_manager as font_manager
# %matplotlib inline

# %%
import random
import numpy as np

# %%
from auto_peak_labeler.utils import get_patch_list
from auto_peak_labeler.engine import PeakFitter
from auto_peak_labeler.modeling.pseudo_voigt2d import PseudoVoigt2D

# %%
def random_display_in_grid(patch_list, ncols = 5, nrows = 10):
    fig   = plt.figure(figsize = (ncols * 2, nrows * 2))
    gspec = fig.add_gridspec( nrows, ncols )
    ax_list = [ fig.add_subplot(gspec[i, j], aspect = 1) for i in range(nrows) for j in range(ncols)]

    num_samples = min(ncols * nrows, len(patch_list))
    random_patch_list = random.sample(patch_list, num_samples)

    for patch_idx, patch in enumerate(random_patch_list):
        ax = ax_list[patch_idx]
        
        vmin = np.mean(patch) - 0 * patch.std()
        vmax = np.mean(patch) + 4 * patch.std()
        im = ax.imshow(patch, vmin = vmin, vmax = vmax)

# %%
def display_fitting(patch, model_params, idx, threshold_level = 0.5):
    ncols = 4
    nrows = 1
    fig   = plt.figure(figsize = (ncols * 2, nrows * 2))
    gspec = fig.add_gridspec( nrows, ncols )
    ax_list = [ fig.add_subplot(gspec[i, j], aspect = 1) for i in range(nrows) for j in range(ncols)]

    # Input image
    ax = ax_list[0]  
    vmin = np.mean(patch) - 0 * patch.std()
    vmax = np.mean(patch) + 4 * patch.std()
    im = ax.imshow(patch, vmin = vmin, vmax = vmax)
    ax.set_title(f'Input Data: {idx}')

    # Modeled image
    model_profile = PseudoVoigt2D(model_params)
    H, W = patch.shape[-2:]
    y = np.arange(0, H)
    x = np.arange(0, W)
    Y, X = np.meshgrid(y, x, indexing = 'ij')
    model_val = model_profile(Y, X)

    ax = ax_list[1]
    ax.imshow(model_val, vmin = vmin, vmax = vmax)
    ax.set_title(f'Model')

    # Residual
    residual_val = model_val - patch
    ax = ax_list[2]
    ax.imshow(residual_val, vmin = vmin, vmax = vmax)
    ax.set_title(f'Residual')

    # Threshold map (half max)
    model_profile.includes_bg = False
    Y, X = np.meshgrid(y, x, indexing = 'ij')
    model_no_bg_val = model_profile(Y, X)
    model_no_bg_val_half_max = model_no_bg_val >= (model_no_bg_val.max() * threshold_level)
    ax = ax_list[3]
    ax.imshow(model_no_bg_val_half_max, vmin = 0, vmax = 1)
    ax.set_title(f'Generated Label')

# %%
# ___/ MAIN WORKER READS DATA \___
# Read sample images and peaks...
img   = np.load("auto_labeler.data.img.npy")
peaks = np.load("auto_labeler.data.peaks.npy")

# %%
peaks_y = peaks[:, 0]
peaks_x = peaks[:, 1]
win_size = 4
uses_padding = True
patch_list = get_patch_list(peaks_y, peaks_x, img, win_size, uses_padding)

# %%
random_display_in_grid(patch_list, ncols = 10, nrows = 4)

# %%
peak_fitter = PeakFitter(num_cpus = 10)

# %%
patch_list[0].shape
# Out:
# (9, 9)

# %%
results = peak_fitter.fit_all_images(patch_list)
# Out:
# 2024-02-13 20:13:01,502	INFO worker.py:1724 -- Started a local Ray instance.

# %%
patch_list[8][0, 0]
# Out:
# 84.01

# %%
4183/84.01**2
# Out:
# 0.592687673673393

# %%
results[8]
# Out:
# <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>321</td><td></td></tr><tr><td># data points</td><td>81</td><td></td></tr><tr><td># variables</td><td>11</td><td></td></tr><tr><td>chi-square</td><td> 4183.78275</td><td></td></tr><tr><td>reduced chi-square</td><td> 59.7683250</td><td></td></tr><tr><td>Akaike info crit.</td><td> 341.506276</td><td></td></tr><tr><td>Bayesian info crit.</td><td> 367.845217</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td>  340.764064 </td><td>  13.6468642 </td><td> (4.00%) </td><td> 341.4800109863281 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> cy </td><td>  4.36375956 </td><td>  0.02048363 </td><td> (0.47%) </td><td> 4.096983995939206 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> cx </td><td>  4.15223741 </td><td>  0.02511320 </td><td> (0.60%) </td><td> 4.030548804453246 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> sigma_y </td><td>  1.49603456 </td><td>  0.10924731 </td><td> (7.30%) </td><td> 3.3613129638325354 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> sigma_x </td><td>  2.34387649 </td><td>  0.20136996 </td><td> (8.59%) </td><td> 3.3613129638325354 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> gamma_y </td><td> -0.99229181 </td><td>  0.12011943 </td><td> (12.11%) </td><td> 3.3613129638325354 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> gamma_x </td><td> -1.29353105 </td><td>  0.13519309 </td><td> (10.45%) </td><td> 3.3613129638325354 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> eta </td><td>  1.35950811 </td><td>  0.13101217 </td><td> (9.64%) </td><td> 0.5 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> a </td><td>  0.32965714 </td><td>  0.35423522 </td><td> (107.46%) </td><td> 0 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> b </td><td> -0.02100083 </td><td>  0.34246551 </td><td> (1630.72%) </td><td> 0 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> c </td><td>  58.7352665 </td><td>  6.36466788 </td><td> (10.84%) </td><td> 80.40249633789062 </td><td>        -inf </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>gamma_x</td><td>eta</td><td>-0.9591</td></tr><tr><td>gamma_y</td><td>eta</td><td>-0.9188</td></tr><tr><td>eta</td><td>c</td><td>-0.9087</td></tr><tr><td>gamma_y</td><td>gamma_x</td><td>0.9002</td></tr><tr><td>gamma_x</td><td>c</td><td>0.8742</td></tr><tr><td>gamma_y</td><td>c</td><td>0.8473</td></tr><tr><td>sigma_x</td><td>c</td><td>0.7829</td></tr><tr><td>sigma_x</td><td>eta</td><td>-0.7717</td></tr><tr><td>sigma_x</td><td>gamma_y</td><td>0.7331</td></tr><tr><td>amp</td><td>gamma_y</td><td>0.7104</td></tr><tr><td>amp</td><td>sigma_y</td><td>-0.6207</td></tr><tr><td>sigma_x</td><td>gamma_x</td><td>0.6126</td></tr><tr><td>amp</td><td>gamma_x</td><td>0.5898</td></tr><tr><td>amp</td><td>eta</td><td>-0.4961</td></tr><tr><td>cy</td><td>gamma_y</td><td>0.4917</td></tr><tr><td>amp</td><td>cy</td><td>0.4820</td></tr><tr><td>sigma_y</td><td>gamma_y</td><td>-0.4556</td></tr><tr><td>amp</td><td>c</td><td>0.4024</td></tr><tr><td>cy</td><td>gamma_x</td><td>0.3819</td></tr><tr><td>cy</td><td>eta</td><td>-0.3755</td></tr><tr><td>cy</td><td>c</td><td>0.3692</td></tr><tr><td>cy</td><td>sigma_y</td><td>-0.3608</td></tr><tr><td>cy</td><td>sigma_x</td><td>0.2957</td></tr><tr><td>amp</td><td>sigma_x</td><td>0.2360</td></tr><tr><td>b</td><td>c</td><td>-0.2334</td></tr><tr><td>sigma_y</td><td>a</td><td>0.2302</td></tr><tr><td>cx</td><td>b</td><td>-0.2268</td></tr><tr>< ...

# %%
num_sample = 10
threshold_level = 1/2
random_sampled_idx_list = random.sample(range(len(patch_list)), k = num_sample)
for idx in random_sampled_idx_list:
    patch = patch_list[idx]
    fitting_result = results[idx]

    display_fitting(patch, fitting_result.params, idx, threshold_level = threshold_level)

# %%
random_sampled_idx_list
# Out:
# [19, 85, 83, 237, 599, 506, 280, 39, 540, 70]

# %% [markdown]
# Interesting patches: 70, 285
